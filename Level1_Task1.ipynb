# %% [markdown]
# Data Preprocessing for Machine Learning

# %% [markdown]
# Loading Data

# %%
import pandas as pd 
#load the dataset
data = pd.read_csv("Black.csv")
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
#describe the dataset to compare missing  values
data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8047.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %% [markdown]
# Resolving Missing Values

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer()
categorical_features = ["Product_ID","Gender","Age","City_Category","Stay_In_Current_City_Years"]
numerical_features = data.columns.drop(categorical_features)

categorical_imputer = SimpleImputer(strategy="most_frequent")
data[categorical_features] = categorical_imputer.fit_transform(data[categorical_features])


numerical_imputer = SimpleImputer(strategy="mean") 
data[numerical_features] = numerical_imputer.fit_transform(data[numerical_features])

# %% [markdown]
# Normalise Numerical Data

# %%
for col in numerical_features:
    mean = data[col].mean()
    std = data[col].std()
    data[col] = (data[col] - mean) / std

# %% [markdown]
# Performing One Hot Encoding to numerical data

# %%
encoded_data = pd.get_dummies(data, columns=categorical_features, drop_first=True)
encoded_data.head()
# Out:
#      User_ID  Occupation  Marital_Status  Product_Category_1  \
# 0  1000001.0        10.0             0.0                 3.0
# 1  1000001.0        10.0             0.0                 1.0
# 2  1000001.0        10.0             0.0                12.0
# 3  1000001.0        10.0             0.0                12.0
# 4  1000002.0        16.0             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase  Product_ID_P00000242  \
# 0            9.842329           12.668243    8370.0                 False
# 1            6.000000           14.000000   15200.0                 False
# 2            9.842329           12.668243    1422.0                 False
# 3           14.000000           12.668243    1057.0                 False
# 4            9.842329           12.668243    7969.0                 False
#
#    Product_ID_P00000342  Product_ID_P00000442  ...  Age_36-45  Age_46-50  \
# 0                 False                 False  ...      False      False
# 1                 False                 False  ...      False      False
# 2                 False                 False  ...      False      False
# 3                 False                 False  ...      False      False
# 4                 False                 False  ...      False      False
#
#    Age_51-55  Age_55+  City_Category_B  City_Category_C  \
# 0      False    False            False            False
# 1      False    False            False            False
# 2      False    False            False            False
# 3      False    False            False            False
# 4      False     True            False             True
#
#    Stay_In_Current_City_Years_1  Stay_In_Current_City_Years_2  \
# 0                         False                          True
# 1                         False                          True
# 2                         False                          True
# 3                         False                          True
# 4                         False                         False
#
#    Stay_In_Current_City_Years_3  Stay_In_Current_City_Years_4+
# 0                         False                          False
# 1                         False                          False
# 2                         False                          False
# 3                         False                          False
# 4                         False                           True
#
# [5 rows x 3650 columns]

# %%
from sklearn.model_selection import train_test_split
X = encoded_data.drop("Purchase",axis=1)
Y = encoded_data["Purchase"]

train_X,valid_X,train_Y,valid_Y = train_test_split(X,Y,test_size=0.2,random_state=50)

# %%
train_X
# Out:
#           User_ID  Occupation  Marital_Status  Product_Category_1  \
# 333839  1003462.0         4.0             0.0                 5.0
# 490401  1003574.0         6.0             1.0                16.0
# 59087   1003125.0         7.0             0.0                 5.0
# 137632  1003300.0         5.0             0.0                18.0
# 244814  1001701.0         4.0             0.0                 8.0
# ...           ...         ...             ...                 ...
# 385156  1005283.0         2.0             1.0                 8.0
# 321502  1001509.0         0.0             0.0                 5.0
# 441633  1001936.0         0.0             0.0                 8.0
# 239499  1000973.0         1.0             1.0                 8.0
# 103904  1004014.0         0.0             1.0                11.0
#
#         Product_Category_2  Product_Category_3  Product_ID_P00000242  \
# 333839            9.842329           12.668243                 False
# 490401            9.842329           12.668243                 False
# 59087             9.842329           12.668243                 False
# 137632            9.842329           12.668243                 False
# 244814           16.000000           12.668243                 False
# ...                    ...                 ...                   ...
# 385156           17.000000           12.668243                 False
# 321502            9.842329           12.668243                 False
# 441633            9.842329           12.668243                 False
# 239499           13.000000           16.000000                 False
# 103904            9.842329           12.668243                 False
#
#         Product_ID_P00000342  Product_ID_P00000442  Product_ID_P00000542  ...  \
# 333839                 False                 False                 False  ...
# 490401                 False                 False                 False  ...
# 59087                  False                 False                 False  ...
# 137632                 False                 False                 False  ...
# 244814                 False                 False                 False  ...
# ...                      ...                   ...                   ...  ...
# 385156                 False                 False                 False  ...
# 321502                 False                 False                 False  ...
# 441633                 False                 False                 False  ...
# 239499                 False                 False                 False  ...
# 103904                 False                 False                 False  ...
#
#         Age_36-45  Age_46-50  Age_51-55  Age_55+  City_Category_B  \
# 333839      False      False      False    False             True
# 490401       True      False      False    False            False
# 59087       False      False      False    False            False
# 137632       True      False      False    False             True
# 244814      False      False      False    False             True
# ...           ...        ...        ...      ...              ...
# 385156      False      False      False    False            False
# 321502      False      False      False    False             True
# 441633       True      False      False    False            False
# 239499      False      False      False    False            False
# 103904      False      False      False    False            False
#
#         City_Category_C  Stay_In_Current_City_Years_1  \
# 333839            False                         False
# 490401            False                          True
# 59087             False                          True
# 137632            False                          True
# 244814            False                          True
# ...                 ...                           ...
# 385156             True                          True
# 321502            False                         False
# 441633             True                          True
# 239499             True                          True
# 103904             True                         False
#
#         Stay_In_Current_City_Years_2  Stay_In_Current_City_Years_3  \
# 333839                         False                          True
# 490401                         False                         False
# 59087                          False                         False
# 137632                         False                         False
# 244814                         False                         False
# ...                              ...                           ...
# 385156                         False                         False
# 321502                         False                          True
# 441633                         False                         False
# 239499                         False                         False
# 103904                          True                         False
#
#         Stay_In_Current_City_Years_4+
# 333839                          False
# 490401                          False
# 59087                           False
# 137632                          False
# 244814                          False
# ...                               ...
# 385156                          False
# 321502                          False
# 441633                          False
# 239499                          False
# 103904                          False
#
# [440054 rows x 3649 columns]

# %%
valid_X
# Out:
#           User_ID  Occupation  Marital_Status  Product_Category_1  \
# 133685  1002627.0         1.0             1.0                 5.0
# 131846  1002237.0         6.0             0.0                 1.0
# 224562  1004578.0         0.0             0.0                 1.0
# 142162  1003929.0         5.0             1.0                 1.0
# 85602   1001218.0        15.0             1.0                14.0
# ...           ...         ...             ...                 ...
# 530103  1003669.0        14.0             0.0                 5.0
# 286888  1002116.0         4.0             1.0                 8.0
# 121471  1000776.0         3.0             0.0                 5.0
# 547328  1002095.0        13.0             1.0                19.0
# 184243  1004411.0         4.0             0.0                 5.0
#
#         Product_Category_2  Product_Category_3  Product_ID_P00000242  \
# 133685            7.000000           12.668243                 False
# 131846            8.000000           17.000000                 False
# 224562            8.000000           16.000000                 False
# 142162            9.842329           12.668243                 False
# 85602            18.000000           12.668243                 False
# ...                    ...                 ...                   ...
# 530103            9.842329           12.668243                 False
# 286888            9.842329           12.668243                 False
# 121471            9.842329           12.668243                 False
# 547328            9.842329           12.668243                 False
# 184243            8.000000           12.668243                 False
#
#         Product_ID_P00000342  Product_ID_P00000442  Product_ID_P00000542  ...  \
# 133685                 False                 False                 False  ...
# 131846                 False                 False                 False  ...
# 224562                 False                 False                 False  ...
# 142162                 False                 False                 False  ...
# 85602                  False                 False                 False  ...
# ...                      ...                   ...                   ...  ...
# 530103                 False                 False                 False  ...
# 286888                 False                 False                 False  ...
# 121471                 False                 False                 False  ...
# 547328                 False                 False                 False  ...
# 184243                 False                 False                 False  ...
#
#         Age_36-45  Age_46-50  Age_51-55  Age_55+  City_Category_B  \
# 133685      False      False      False    False             True
# 131846       True      False      False    False             True
# 224562      False      False      False    False            False
# 142162      False      False      False    False             True
# 85602       False      False      False     True             True
# ...           ...        ...        ...      ...              ...
# 530103      False      False      False    False            False
# 286888      False      False      False    False             True
# 121471      False      False      False    False             True
# 547328      False      False      False     True            False
# 184243      False      False      False    False            False
#
#         City_Category_C  Stay_In_Current_City_Years_1  \
# 133685            False                         False
# 131846            False                          True
# 224562            False                         False
# 142162            False                          True
# 85602             False                         False
# ...                 ...                           ...
# 530103            False                         False
# 286888            False                         False
# 121471            False                          True
# 547328             True                          True
# 184243            False                         False
#
#         Stay_In_Current_City_Years_2  Stay_In_Current_City_Years_3  \
# 133685                          True                         False
# 131846                         False                         False
# 224562                         False                         False
# 142162                         False                         False
# 85602                          False                         False
# ...                              ...                           ...
# 530103                          True                         False
# 286888                         False                         False
# 121471                         False                         False
# 547328                         False                         False
# 184243                         False                          True
#
#         Stay_In_Current_City_Years_4+
# 133685                          False
# 131846                          False
# 224562                           True
# 142162                          False
# 85602                           False
# ...                               ...
# 530103                          False
# 286888                           True
# 121471                          False
# 547328                          False
# 184243                          False
#
# [110014 rows x 3649 columns]
